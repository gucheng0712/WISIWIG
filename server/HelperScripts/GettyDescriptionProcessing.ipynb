# %%
import pandas as pd
from pandas import ExcelFile
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk import pos_tag


df = pd.read_excel('getty_dataset/TECH 2709 Getty Dataset.xlsx', sheet_name='Generated Descriptions')

# delete empty rows
#df = df.drop([0, 1, 2, 3, 4], axis=0)
#df = df.drop(df.index[0:4], axis=0)

print("df.head():")
display(df.head())

print("df.columns:")
display(df.columns)

df_responses = df['Response']  # [0:50]

print("# responses:")
print(df_responses.count())
# Out:
# df.head():
#      Name                  Prompt  \
# 0  Nikita         "happy person "
# 1     NaN           "sad person "
# 2     NaN  "surprised and angry "
# 3     NaN    "fearful young man "
# 4     NaN        happy young man
#
#                                             Response   Reject
# 0  .")\nKnown for his skillfully rendered charact...      NaN
# 1  下,meaning Da, or French for Child). According ...      NaN
# 2  urn-possessed woman as he embarks upon a hunt ...      NaN
# 3  ��was knocked over and beaten to death while a...  violent
# 4  」\nAmong the countless nymphs whom Mary Magdal...      NaN
# df.columns:
# Index(['Name', 'Prompt', 'Response', 'Reject'], dtype='object')
# # responses:
# 155

# %%
responses = []
for i in range(df_responses.count()):
    # print(df_titles[i])
    response = df_responses[df_responses.index[i]]
    if(not pd.isnull(response)):  # ignore empty rows
        response = response.replace('\n', '')  # remove newline characters
        response = response.strip()  # remove whitespace
        print("[", i, "] ", response)
        responses.append(response)
# Out:
# [ 0 ]  .")Known for his skillfully rendered characters, complex gestures, and varied animation styles, Edgar Degas often epitomized the visionary. Having been gifted the manuscript of Ovid's Metamorphoses in 6003, Degas traveled the world in
# [ 1 ]  下,meaning Da, or French for Child). According to Herodotus,risenas, or grapes, were used to glaze Roman columns and battlements, which then decorated the temple's walls. Ludovico Carracci here
# [ 2 ]  urn-possessed woman as he embarks upon a hunt for elusive drake cubs. CollectorsReturning to his hunting grounds, the distraught woman leans on a rope frame made of obsidian, attempting to pull herself up by her hair
# [ 3 ]  ��was knocked over and beaten to death while attempting to escape the clutches of the king and queen. Suspecting that the condemned man was a kidnapper, the kidnapper�s identity was revealed as that of the new governor of the kingdom of
# [ 4 ]  」Among the countless nymphs whom Mary Magdalene grieved most intensely were the handsome young men whom she depicted most fondly--the peacocks whom she depicted most fondly--as well as her jealous older sister, Mary Extremely Little. The nymphs stand on the precip
# [ 5 ]  !" L'Anse wrote, "I shall make a bed in his garden, and when it is time to let him into the world, I shall set it on fire with his naked body against the mantel."�L'Avare (1604-1714), the French artist who
# [ 6 ]  」 Edward conveys the moment's somber self-indulgence.  Yet the intimacy and serenity of his life also includes the freshness of his disposition, the changing of the season in the distance, and the frequency of lullaby songs.  Married in 1752, the young
# [ 7 ]  has acquired some shrewd observation and skill as he makes sudden advances toward the left wing of the room. The speaker assumes the form of a youth, leaning on one arm and extending out sharply and dramatically to address the viewer at a time.  This subject comes up four times in the play,
# [ 8 ]  with a thoroughly classical composition. The painting's linear composition is characteristic of Bartolommeo�  (1679 � 1707) of the River Titian, a prominent Florentine artist who influenced Pino a generation later. Bartolommeo�s uncompromising treatment
# [ 9 ]  (Aberdeen: Duke of Southampton), a radical reformer and attorney. Against the sober, tragic landscape, his character is more like a short film than a full-length. For this, the leading Englishman, would have to go back to his native land for some sort of document
# [ 144 ]  and men who are said to have been responsible for torturing Mary (Matthew 16:35-44). The bodies were recovered from a small wooded area within the traditional family of Martyrs of Christ, the Tolerated Saints. These souls were likely victims of religious cult
# [ 145 ]  that invaded India around 1400. According to legend, King Harpocrates of India invaded a jealous southern kingdom, and executed a group of his own royalty. After several failed attempts to slay him, King Harpocrates successfully subdued all who opposed him, and he was executed for
# [ 146 ]  This painting was once on display in the Verona conservatory in Florence.Using a combination of water and chalk, Giulio Credori used a combination of light and shadow to create a shimmering surface that could be identified by the folds of the chalk lines behind
# [ 147 ]  were created for each other. The leftmost figure depicts a boy and girl, who are seen gazing sadly at one another as if frightened. They are not intended to be identified by their unusual faces, which might indicate social or psychological roles.The painting was commissioned by
# [ 148 ]  What he saw was not a scene from a typical fantasy story, but rather one in which one could identify many of the elements: light, shadow, and warm colors, which formed the background to many of the surface areas of this painting. Above all, though,
# [ 149 ]  This painting depicts a youth attempting to follow a pipe dream: during the painting's final resting moment, an unknown person reaches up and pulls a pipe up the child's chest. Oddly, though, the pipe is only partially illuminated, giving the painting's owner a
# [ 150 ]  she is often portrayed as a kind, kindling angel, whom the Church has recognized as a faithful patron. The Catholic Church interpreted these words with greater sensitivity than it had in the early 20th century, and some scholars believe that Christ's Mercy may have been intended as
# [ 151 ]  A priestess is abducted by the demons, while her lover, Saint Vianney, is captured and tortured. Vianney turns to a mystic, Saint Sebastian, who gives impassioned recitations of mantras to the priestess. His impetuous expression
# [ 152 ]  with an extraordinary rendition of the ancient Egyptian scene from The Odyssey. Here the sculptor employed an unusual approach to forming a scene that contrasted with conventional perspective, and was also sensitive to the emotional and psychological effects of light.The figure of a seated man with His features plain
# [ 153 ]  while still remaining emotionally stable. These are figures that have captivated audiences since their conception, yet often failed to achieve their originality.In the 1700s, artists began creating decorative or decorative garments in response to the popular demand for a fashionable, open-topped
# [ 154 ]  Her hair is very long, but she still leans forward and poses with a dignified air.In order to describe the female figure, S�vres and his son copied scenes from the ancient Greek and Roman mythology. Titian's work emphasizes the fleeting nature of

# %%
MIN_LENGTH_SENTENCE = 10

chosen_response = []

for response in responses:
    # sepreate a paragraph by sentences
    response_sentences = sent_tokenize(response)
    print("\n### processing response..")
    print("# sentences: ", len(response_sentences))

    # loop through each sentence in the tokenized sentence list
    for sentence in response_sentences: 
                
        sentence_tag =pos_tag(word_tokenize(sentence))
        # Check element if exists in list of list
        hasNoun = 'NN' in (tag for word_tag in sentence_tag for tag in word_tag) 
        hasVerbG = 'VBG' in (tag for word_tag in sentence_tag for tag in word_tag)
        hasVerbD = 'VBD' in (tag for word_tag in sentence_tag for tag in word_tag)
        if not (hasNoun and (hasVerbD or hasVerbG)):
            print("- removing Sentences doesn't have noun or verb:")
            print(sentence)
            response_sentences.remove(sentence)  
        elif(len(sentence) < MIN_LENGTH_SENTENCE):
            print("- removing too short sentence:")
            print(sentence)
            response_sentences.remove(sentence)
        elif(sentence[len(sentence)-1] != '.'):
            # sentence does not end with '.'
            print("- removing incomplete sentence:")
            print(sentence)
            response_sentences.remove(sentence)
        elif (not sentence[0].isupper()):# if not starting as capital word which means the word is broken
            print("- removing characters not beginning with letters:")
            print(sentence)
            response_sentences.remove(sentence)

    for i in range(len(response_sentences)):
        sentence = response_sentences[i]
        if(not sentence[0].isalnum()):
            print("- removing characters not beginning with letters:")
            print(sentence)
            while(not sentence[0].isalnum()):
                sentence = sentence[1:]
            response_sentences[i] = sentence
      

    print("\n# sentences after processing: ", len(response_sentences))

    
    for i in range(len(response_sentences)):
        sentence = response_sentences[i]
        sentence = bytes(sentence, 'utf-8').decode('utf-8', 'ignore')
        print("[", i, "] ", sentence)
        chosen_response.append(sentence)


print(chosen_response)
# Out:
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# .
# - removing incomplete sentence:
# Having been gifted the manuscript of Ovid's Metamorphoses in 6003, Degas traveled the world in
# - removing characters not beginning with letters:
# ")Known for his skillfully rendered characters, complex gestures, and varied animation styles, Edgar Degas often epitomized the visionary.
#
# # sentences after processing:  1
# [ 0 ]  Known for his skillfully rendered characters, complex gestures, and varied animation styles, Edgar Degas often epitomized the visionary.
#
# ### processing response..
# # sentences:  3
# - removing characters not beginning with letters:
# 下,meaning Da, or French for Child).
# - removing Sentences doesn't have noun or verb:
# Ludovico Carracci here
#
# # sentences after processing:  1
# [ 0 ]  According to Herodotus,risenas, or grapes, were used to glaze Roman columns and battlements, which then decorated the temple's walls.
#
# ### processing response..
# # sentences:  2
# - removing Sentences doesn't have noun or verb:
# urn-possessed woman as he embarks upon a hunt for elusive drake cubs.
#
# # sentences after processing:  1
# [ 0 ]  CollectorsReturning to his hunting grounds, the distraught woman leans on a rope frame made of obsidian, attempting to pull herself up by her hair
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
# ��was knocked over and beaten to death while attempting to escape the clutches of the king and queen.
#
# # sentences after processing:  1
# [ 0 ]  Suspecting that the condemned man was a kidnapper, the kidnapper�s identity was revealed as that of the new governor of the kingdom of
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
# 」Among the countless nymphs whom Mary Magdalene grieved most intensely were the handsome young men whom she depicted most fondly--the peacocks whom she depicted most fondly--as well as her jealous older sister, Mary Extremely Little.
#
# # sentences after processing:  1
# [ 0 ]  The nymphs stand on the precip
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# !"
# - removing Sentences doesn't have noun or verb:
# "�L'Avare (1604-1714), the French artist who
#
# # sentences after processing:  1
# [ 0 ]  L'Anse wrote, "I shall make a bed in his garden, and when it is time to let him into the world, I shall set it on fire with his naked body against the mantel.
#
# ### processing response..
# # sentences:  3
# - removing characters not beginning with letters:
# 」 Edward conveys the moment's somber self-indulgence.
# - removing Sentences doesn't have noun or verb:
# Married in 1752, the young
#
# # sentences after processing:  1
# [ 0 ]  Yet the intimacy and serenity of his life also includes the freshness of his disposition, the changing of the season in the distance, and the frequency of lullaby songs.
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# has acquired some shrewd observation and skill as he makes sudden advances toward the left wing of the room.
# - removing Sentences doesn't have noun or verb:
# This subject comes up four times in the play,
#
# # sentences after processing:  1
# [ 0 ]  The speaker assumes the form of a youth, leaning on one arm and extending out sharply and dramatically to address the viewer at a time.
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# with a thoroughly classical composition.
# - removing Sentences doesn't have noun or verb:
# Bartolommeo�s uncompromising treatment
#
# # sentences after processing:  1
# [ 0 ]  The painting's linear composition is characteristic of Bartolommeo�  (1679 � 1707) of the River Titian, a prominent Florentine artist who influenced Pino a generation later.
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# (Aberdeen: Duke of Southampton), a radical reformer and attorney.
# - removing incomplete sentence:
# For this, the leading Englishman, would have to go back to his native land for some sort of document
#
# # sentences after processing:  1
# [ 0 ]  Against the sober, tragic landscape, his character is more like a short film than a full-length.
#
# ### processing response..
# # sentences:  3
# - removing characters not beginning with letters:
# has the look of a child sodomizing an old woman in the street.
# - removing Sentences doesn't have noun or verb:
# He may have simply been an old man's model,
#
# # sentences after processing:  1
# [ 0 ]  His great advantage is his ability to give facial expressions since the smaller the head, the wider, more eminent his other features become in a woman's body.
#
# ### processing response..
# # sentences:  4
# - removing characters not beginning with letters:
# who ended his nineteen-seventeenth year with the utmost in extravagance--thus outlasting appetites.
# - removing Sentences doesn't have noun or verb:
# Men with exaggerated sash twists around their heads.
#
# # sentences after processing:  2
# [ 0 ]  At his left a woman holds a wreath, while a man with a cape and a hood holds a jewel.
# [ 1 ]  A woman
#
# ### processing response..
# # sentences:  4
# - removing Sentences doesn't have noun or verb:
# .
# - removing Sentences doesn't have noun or verb:
# The painting is based on a painting by Ovid (ca.
# - removing characters not beginning with letters:
# ''Separated from his family by a violent storm, Samuel has retreated to the shade of a tree by his side, where he engages in merry adventuring.
#
# # sentences after processing:  2
# [ 0 ]  Separated from his family by a violent storm, Samuel has retreated to the shade of a tree by his side, where he engages in merry adventuring.
# [ 1 ]  325 - 337) that was also by Rogelio Landes
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# on this perfectly smooth surface in the early 1600s.
# - removing incomplete sentence:
# For this, Oldenburg intended as a piece of art a nude woman
#
# # sentences after processing:  1
# [ 0 ]  The grain is smooth, creamy, and quite a departure from the crinkled silver and gold that characterized so many other porcelain prints made during this period.
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# My features are not ready for prime time.
# - removing Sentences doesn't have noun or verb:
# Her gently sculpted eyes tremble
#
# # sentences after processing:  1
# [ 0 ]  I sit in a reclining position on a chair and lean against the wall while a woman in a low sitting position stares down from her terraced terrace with an expression of concern.
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
# 『Martín de los Muertos LeBlancs, Nascimento de los Ruiz Sinalitiros en el Gobelante, Bern, 1758–1770], aged seventeen (about to become three when he married Percurrea).
#
# # sentences after processing:  1
# [ 0 ]  Día Ferreira was appointed
#
# ### processing response..
# # sentences:  2
# - removing Sentences doesn't have noun or verb:
# with a large, angular profile, expressive roundness, and a shaggy beard.
#
# # sentences after processing:  1
# [ 0 ]  His favorite subject, the small lion--a symbol of peasant status in Israel--has been suggested earlier by Tzachi Bright (1713�1816), who observed that the joyful young man would be
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# !
# - removing incomplete sentence:
# A phrase that writers and painters of the 1790s used to describe scenes ranging from merry songs and festive characters to
# - removing characters not beginning with letters:
# "This procession of picturesque peasant scenes is called a tous-vous de l'ame (tous'-vaous-il-le-mi-ame)?
#
# # sentences after processing:  1
# [ 0 ]  This procession of picturesque peasant scenes is called a tous-vous de l'ame (tous'-vaous-il-le-mi-ame)?
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
#  shouting, clapping, and engaging in sexual activities, and this may suggest that Fascism was born in Italy, where such activities were encouraged and encouraged by the British Crown.
#
# # sentences after processing:  1
# [ 0 ]  As was customary in the prime of Italian civil government, the Crown appointed members of the press and royal courts with important
#
# ### processing response..
# # sentences:  4
# - removing Sentences doesn't have noun or verb:
# .
# - removing Sentences doesn't have noun or verb:
# Pairs of artists painted and presented for
# - removing characters not beginning with letters:
# ")In so doing, he recognized that his subject already possessed considerable literary talent.
#
# # sentences after processing:  2
# [ 0 ]  In so doing, he recognized that his subject already possessed considerable literary talent.
# [ 1 ]  According to Vincent, Fran�ois-Joseph D�rer was once considered one of France's most prolific writers and essayists, and his writings often circulated in the press.
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# has filled all three paintings.
# - removing incomplete sentence:
# Ludovico del Rios presented the portrait in mid-1852, two years after receiving his
#
# # sentences after processing:  1
# [ 0 ]  Responding to the viewer's request for a pose that encourages foreshortening, he encourages the viewer to sit still and recall his thoughts for as long as possible.
#
# ### processing response..
# # sentences:  3
# - removing characters not beginning with letters:
# on the right, with the tree trunk helping to balance the irises of the two figures.
# - removing Sentences doesn't have noun or verb:
# Above all, the cornucopia, the sum of its parts, entices us to contemplate the
#
# # sentences after processing:  1
# [ 0 ]  Tender grapes, rich in vitamin C, may even be added to the blend to taste.
#
# ### processing response..
# # sentences:  2
# - removing incomplete sentence:
# of the triumph of the human spirit over matter, which the poet Eustache de Morabito attributed to "the overturning of the form by which matter has moved ... in the process of being overturned by matter."
#
# # sentences after processing:  1
# [ 0 ]  The anticipatory pose, as adopted by Johann Karl Wilhelm von Haas, emphasizes
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
# ified the spirit of the founder, who often used his unkempt mustache and large, open mouth to taunt his subjects.
#
# # sentences after processing:  1
# [ 0 ]  He used subtle but powerful strokes to show off his athletic strength and musculara
#
# ### processing response..
# # sentences:  1
# - removing incomplete sentence:
# , wearing gold-tinged robes, with long black hair who seemed to be sculpted from ancient Egyptian woodcut, with eyes that gleamed red from the deep sockets; a boyish face,
#
# # sentences after processing:  0
#
# ### processing response..
# # sentences:  2
# - removing Sentences doesn't have noun or verb:
# or confidence], perhaps for nothing more than his own selflessness or determination to survive in the face of tyranny and injustice."
#
# # sentences after processing:  1
# [ 0 ]  Thus the emperor, now crowned by King David, began his conquest of Babylon and
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
# ified that popular theatrical character, Fortuna, portrayed with more sophistication in Western art than in Japanese.
#
# # sentences after processing:  1
# [ 0 ]  Fortuna, a young girl in a yellow robe, kneels to contemplate her father,
#
# ### processing response..
# # sentences:  1
# - removing incomplete sentence:
# It was not until the end that he began to experience what is perhaps the most tragic episode of his life, his own suicide.The angel Tiamat appeared out of nothing
#
# # sentences after processing:  0
#
# ### processing response..
# # sentences:  4
# - removing characters not beginning with letters:
# to him; his eyes were pale but he was calm.
# - removing Sentences doesn't have noun or verb:
# His manner is unperturbed.
#
# # sentences after processing:  2
# [ 0 ]  Though pale he was not greedy or greedy� he was simply looking for love.
# [ 1 ]  In high spirits he holds
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
# with long beard who used to watch over the church from the stands.
#
# # sentences after processing:  1
# [ 0 ]  The story relates to a story with contemporary Christian evangelist Giorgio Vasari, who was visiting Rome as consul to Holland
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# wearing the traditional robes.
# - removing Sentences doesn't have noun or verb:
# Gentile's
#
# # sentences after processing:  1
# [ 0 ]  In this retelling of the founding of the Jewish community of Palisades, Luigi Gentile was one of the first collectors to study religious figures in detail.
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
# have been shown wearing skullcap and skullpieces, likely from a series of funerary scenes.
#
# # sentences after processing:  1
# [ 0 ]  The figures' facial features are similar to those of ancient Egyptian art (these figures, which were usually empty
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# from an exotic landscape and an exotic setting.
# - removing incomplete sentence:
# To watch her playfully watch her lover twist was one
#
# # sentences after processing:  1
# [ 0 ]  She combines a sensuality bordering on eroticism with a warm, sympathetic gaze that is utterly penetrating.
#
# ### processing response..
# # sentences:  1
# - removing incomplete sentence:
# in the crowd, one hand poised on her thighs, the other clasped on to her chest like lovers.For her part, the young woman in the foreground is beautiful and unpretentiously
#
# # sentences after processing:  0
#
# ### processing response..
# # sentences:  2
# - removing Sentences doesn't have noun or verb:
# of color and ethnicities, with curly hair and a powerful sense of composition.
# - removing characters not beginning with letters:
# "I never would have imagined that the greatest artist of all time would be his pupil, the greatest artist in the
#
# # sentences after processing:  1
# [ 0 ]  I never would have imagined that the greatest artist of all time would be his pupil, the greatest artist in the
#
# ### processing response..
# # sentences:  2
# - removing Sentences doesn't have noun or verb:
# at odds with nature; the goddess Athena looks on with a grimace.
#
# # sentences after processing:  1
# [ 0 ]  With only her bare hands she makes no effort to move, instead forming a circle around herself in an unusual gesture of artifice
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
# of southern Europe were perhaps the closest we have to a functioning civilization.
#
# # sentences after processing:  1
# [ 0 ]  The artists portrayed the life-like landscape and sky, the rich and expansive architecture and setting, the soft tones, the soft cloth
#
# ### processing response..
# # sentences:  3
# - removing characters not beginning with letters:
# standing in front of him, their faces filled with anger.
# - removing Sentences doesn't have noun or verb:
# Their anger is shared by all the members of the Barit
#
# # sentences after processing:  1
# [ 0 ]  Their faces are full of resentment for what was gained by the Crusaders.
#
# ### processing response..
# # sentences:  3
# - removing incomplete sentence:
# standing on a white carpet, looking at an observer with glee and concern."
# - removing Sentences doesn't have noun or verb:
# At war with humanity
#
# # sentences after processing:  1
# [ 0 ]  This is the second episode of the Nineveh series, based on the popular Bible story.
#
# ### processing response..
# # sentences:  3
# - removing characters not beginning with letters:
# sitting on a stool, their faces contorted beneath their light, their shoulders hunched.
# - removing Sentences doesn't have noun or verb:
# To illustrate the complex social position of this ethnic group,
#
# # sentences after processing:  1
# [ 0 ]  They are identified by broad shoulders and elongated heads.
#
# ### processing response..
# # sentences:  1
# - removing Sentences doesn't have noun or verb:
# ) to perform a variety of rites and perform miraculous occupations: a maidservant devours her husband's flesh, a wily warrior sits with her daughter in the woods, and a nymph falls
#
# # sentences after processing:  0
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
# were dressed in elaborate costumes, each displaying a particular attribute: a fish hat, a fish tail, wings, and a skull.
#
# # sentences after processing:  1
# [ 0 ]  In addition, the woman's face and arms were adorned in elaborate decorations
#
# ### processing response..
# # sentences:  3
# - removing characters not beginning with letters:
# in a suit and walking briskly through a park.
# - removing Sentences doesn't have noun or verb:
# In the upper
#
# # sentences after processing:  1
# [ 0 ]  She wears a long white gown with a light blue lining and a white beret, which she has joined into a turban.
#
# ### processing response..
# # sentences:  4
# - removing Sentences doesn't have noun or verb:
# .
# - removing Sentences doesn't have noun or verb:
# The red
#
# # sentences after processing:  2
# [ 0 ]  The woman is covered in scars from a fight and a gash on her wrist.
# [ 1 ]  She has a small pained expression and sits on a patch of patch where her head was cut.
#
# ### processing response..
# # sentences:  2
# - removing Sentences doesn't have noun or verb:
# and a nymph crying.)
#
# # sentences after processing:  1
# [ 0 ]  Possessed of a brooch and a hooded head, the sisters, now identified as Eliezer and Adele, hunt monkeys with their bare hands.
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# are seen in the dark.
# - removing Sentences doesn't have noun or verb:
# In the scene, a distraught woman sits while
#
# # sentences after processing:  1
# [ 0 ]  This scene was inspired by the iconic scene from an episode of the classic 1950s drama, The Man in the High Castle.
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# , respectively, with dark looks.
# - removing Sentences doesn't have noun or verb:
# The pose is indicative of a female profile of the figure, as depicted on the left-hand side of this
#
# # sentences after processing:  1
# [ 0 ]  The pair frequently appear side by side, gazing downward.
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# with a face of a mirror.
# - removing incomplete sentence:
# He wears a yellow hooded jacket with a red border around the shoulders and
#
# # sentences after processing:  1
# [ 0 ]  A young boy dressed in bright red and blue holds a book in his left hand.
#
# ### processing response..
# # sentences:  3
# - removing characters not beginning with letters:
# who was clearly having a hard time with a conversation and who then turned and ran away.
# - removing incomplete sentence:
# The male model was not dressed
#
# # sentences after processing:  1
# [ 0 ]  The young lady was clearly tired after a day's work on the factory floor.
#
# ### processing response..
# # sentences:  2
# - removing Sentences doesn't have noun or verb:
# " and "a gentleman, not of the court of Versailles," among contemporaries of Madame de Flanders.
#
# # sentences after processing:  1
# [ 0 ]  It has been rumored that the story about the "militant, theatrical Madame de
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# .
# - removing Sentences doesn't have noun or verb:
# As the story unfolds, a man named Tobias tries to stop the monster, but has little success
#
# # sentences after processing:  1
# [ 0 ]  To this end, she hangs from a tree while an errant rock rumbles against the horizon.
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# In her late-eighteenth-century tomb in Thebes, a woman named Eustard-la-Maigne holds a picture of Christ.
# - removing incomplete sentence:
# The woman's gestures imply sincerity -- and she gestures in the appropriate manner, perhaps referring to her son's likeness.In a series of scenes from the cult of Santo Stefano del Corse in the San Sebastian Mountains, a group of young, muscular figures pose in the central wilderness of the desert, observing the spectacular colors, deep textures, and enigmatic music
#
# # sentences after processing:  1
# [ 0 ]  The Virgin's face grasps the Christ child in her arm and her cheeks turn red at the sight.
#
# ### processing response..
# # sentences:  7
# - removing Sentences doesn't have noun or verb:
# No Man's Sky arrives on a beautiful autumn Sunday morning in 2372 near the edge of the constellation of Gerber which also symbolize the Ten Years' War.
# - removing Sentences doesn't have noun or verb:
# A member of a wealthy family takes shelter in a small open area in this undated image released on September 15, 2013.
#
# # sentences after processing:  5
# [ 0 ]  The goddess of war sits on a pedestal, gazing into the distance.
# [ 1 ]  Behind the goddess, Venus flies at a distant height, looking at the horizon and smiling as she does so.
# [ 2 ]  Around her, a group of men strut around, forming elaborate human forms.
# [ 3 ]  In the background, arrows point to clouds, the Virgin Mary and King Philip and Mary Magdalene standing on the outskirts of the scene.
# [ 4 ]  The group includes the family's two daughters,
#
# ### processing response..
# # sentences:  7
# - removing Sentences doesn't have noun or verb:
# with their bare hands.
# - removing Sentences doesn't have noun or verb:
# In this picture, a member of the group of the nude women is shown surrounded by the nude figure of a man with a beard.
# - removing incomplete sentence:
# After her portrait was destroyed by her accomplice, Catherine the Great
#
# # sentences after processing:  4
# [ 0 ]  Only the most beautiful and graceful faces, or the very gentle wrinkles of their skin, have been recognized as such.
# [ 1 ]  In the past years, we have encountered so many different types of this painting that painting has become known as a symbol of beauty and fragility, often representing the harmony of a composition.
# [ 2 ]  The figure of the bald man has been adopted by contemporary paintings on the ground floor of a fashionable city place.
# [ 3 ]  Although this group of artists may have painted many works, they were not the only nude women to appear here.
#
# ### processing response..
# # sentences:  3
# - removing characters not beginning with letters:
# with their distinctive faces, the face of a saintly figure smiling and the face of a Christian saint looking out at the world, one character at a time.
# - removing incomplete sentence:
# 2 (1920), which was probably commissioned by a collector in Rome.Through the light blue of the base, a woman in a long, white gown, with her hands folded in a somber manner, looks at
#
# # sentences after processing:  1
# [ 0 ]  The painting has been exhibited in several museums and is part of an extensive series, which includes the Gallerist No.
#
# ### processing response..
# # sentences:  6
# - removing Sentences doesn't have noun or verb:
# to watch and chat with.
# - removing Sentences doesn't have noun or verb:
# The Madonna and Child is the central object of the theme of chastity.Rosa of Spenevara is the goddess of the autumn, the Winter, the seasons.
# - removing incomplete sentence:
# Over time, the cityscape began to change into
#
# # sentences after processing:  3
# [ 0 ]  The young man in the middle of the circle is one of the founders.Although there were several classical ruins in the city of Verona, one was the centerpiece of an elaborate cult of the Madonna and Child.
# [ 1 ]  Originally from southern Italy, the Italian region with its rich woods, lush fountains, and cool seasons was captured by the British artist William Barberini in 1776.
# [ 2 ]  Barberini spent many years painting the cityscape of Verona, which features trees and a rich fabric.
#
# ### processing response..
# # sentences:  4
# - removing Sentences doesn't have noun or verb:
# in a rocky cliff in southern France.
# - removing Sentences doesn't have noun or verb:
# Through her gestures and gestures of gesture, the goddess vanishes into the distance, the subject of this
#
# # sentences after processing:  2
# [ 0 ]  During the first decade of the twenty-first century there has been a dramatic uptick in the number of picturesque picturesque places.
# [ 1 ]  The French landscape painter Jean-Baptiste Renoir created this powerful portrait of a group of frightened people, the subject of the scene from the French genre of Le Perla.An ancient goddess poses behind a burning fire.
#
# ### processing response..
# # sentences:  4
# - removing incomplete sentence:
# who was never quite ready to reveal himself, except perhaps for the gesture, which was entirely appropriate to the moment."
# - removing Sentences doesn't have noun or verb:
# For this he was rewarded with
#
# # sentences after processing:  2
# [ 0 ]  The work was first published in 1727.
# [ 1 ]  The artist James Daubert made many similar works in his studio until the late 1700s, when he left work for his own project, where he painted with a lighter sensuality and a brush.I do not know whether to smile or be sad, which the man himself states in his final moments.
#
# ### processing response..
# # sentences:  5
# - removing characters not beginning with letters:
# was identified by his casual dress and elegant manner.
# - removing Sentences doesn't have noun or verb:
# The gentleman's demeanor is typical of the aristocratic style of the 1750s or 1800s.
# - removing incomplete sentence:
# The bust is said to have been designed
#
# # sentences after processing:  2
# [ 0 ]  His eyes, a warm smile, and a cool chin characterize his self-portrait.
# [ 1 ]  The bust is also part of a loose frame of metal, and sits against a dark background.This artist made this bust at the request of a friend, and it belongs to the Museum of Medieval History in Florence.
#
# ### processing response..
# # sentences:  3
# - removing characters not beginning with letters:
# in the history of the world; a kind of saint whose moral purity was achieved through suffering and sacrifice.I have yet to finish one of the most beautiful, intimate, and satisfying pieces of contemporary European art.
# - removing Sentences doesn't have noun or verb:
# This sculptural representation of Christ is not a traditional depiction of Christ, but one made in the 1600s, based more upon a study of architecture than from an act of devotion
#
# # sentences after processing:  1
# [ 0 ]  The figure of Christ in the lower left corner, flanked by the saints and angels, both very well crafted.
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
# in black clothing, with the words "In the dark of night the ghost of Sir Anthony Barret, aged 14, has risen for his feast at the Temple of Heracles," written in the reverse corner, reaches the altar with an open palm, knowing that his friend Erasmus, son of King Aeneas of Spain, the eldest son of the Venetian emperor, and probably the founder of Venice, shall soon follow him.
# - removing characters not beginning with letters:
# )From this large painting, it was extremely difficult for
#
# # sentences after processing:  1
# [ 0 ]  From this large painting, it was extremely difficult for
#
# ### processing response..
# # sentences:  4
# - removing Sentences doesn't have noun or verb:
# Though the goddess, the goddess of love, holds the fire, the hero fires it with his right hand.
# - removing incomplete sentence:
# The god is defeated and defeated.The hero whose sword was cut off in combat and the woman who carried
#
# # sentences after processing:  2
# [ 0 ]  This is a terrifying tale of war and death.The hero of the old tale, the god of fire and brimstone, is surrounded by flames.
# [ 1 ]  Though she holds a fire, he is unable to find a suitable spot through the use of the fire extinguishing rod.
#
# ### processing response..
# # sentences:  5
# - removing characters not beginning with letters:
# th each other, the two groups forming a single living thing.
# - removing Sentences doesn't have noun or verb:
# On the ground, in the winter, flowers and trees and stones decorate the landscape.On the left-hand side, an unidentified figure appears behind a tree, surrounded by his or her close-knit group.
# - removing Sentences doesn't have noun or verb:
# Above, a young woman looks down from the sky at the figures
#
# # sentences after processing:  2
# [ 0 ]  During winter, they carry a young woman down the valley to her land.
# [ 1 ]  They all seem to exist in an imaginary space, as if from outside.
#
# ### processing response..
# # sentences:  3
# - removing characters not beginning with letters:
# with their distinctive faces, the face of a saintly figure smiling and the face of a Christian saint looking out at the world, one character at a time.
# - removing incomplete sentence:
# 2 (1920), which was probably commissioned by a collector in Rome.Through the light blue of the base, a woman in a long, white gown, with her hands folded in a somber manner, looks at
#
# # sentences after processing:  1
# [ 0 ]  The painting has been exhibited in several museums and is part of an extensive series, which includes the Gallerist No.
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
# who sit before the window, surrounded by statues of their goddess Serenity and her angels, the Virgin, and Child and the God-fearing Man, all represented by the headly proportions of the two angels and Mary Magdalene, all surrounded by a cloud of heavenly rays.
#
# # sentences after processing:  1
# [ 0 ]  As in the other books of the Bible, in this picture of a group of elderly people and their godly role models, the viewer may be forgiven for misreading the subject in the initial pages.This
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# to death.
# - removing incomplete sentence:
# His gestures, gestures of triumph, and the gesture of affirming the authority of his master, Diocletian, both describe this genre of music.John Calvin (about 1793-1812) was an accomplished Calvinist and a member of the Protestant Order of Santa Fe, where he held religious office from about
#
# # sentences after processing:  1
# [ 0 ]  His style is often considered crude but he is also interested in the historical aspect of religious imagery, notably in the altarpieces of Christ and the cross.
#
# ### processing response..
# # sentences:  4
# - removing Sentences doesn't have noun or verb:
# stands, surrounded by the ruins of the town, before dawn on a Sunday morning.
# - removing Sentences doesn't have noun or verb:
# The figures have a rather aristocratic quality about them.
#
# # sentences after processing:  2
# [ 0 ]  The figures are a mixture of classical architecture, ancient Greek mythology, and mythological details.
# [ 1 ]  Scholars such as van Vogt, who viewed the figures in a more aristocratic light, may have meant that they had less aristocratic features or that their figureheads were more elongated, emphasizing the refinement of the figuremaking process.Beneath Bresson
#
# ### processing response..
# # sentences:  4
# - removing Sentences doesn't have noun or verb:
# in a hooded cap and a taupe dress, the only sign of an artistic career.
# - removing incomplete sentence:
# The figure stands at attention, gazing outward in a manner suggestive of a pastime of contemplation.The figure of a young woman in costume appears in the Bible
#
# # sentences after processing:  2
# [ 0 ]  Her head turns from the left to the right, which correspond to the characteristic features of the figure's hairstyle.
# [ 1 ]  A small round bead of incense hung from the right sleeve of her tunic and her fingers were pressed into her flesh.
#
# ### processing response..
# # sentences:  4
# - removing Sentences doesn't have noun or verb:
# in her eyes, the bright red cap and the bright white tassels.
# - removing incomplete sentence:
# She was said to have been the goddess of the sunset, or when the moon and stars
#
# # sentences after processing:  2
# [ 0 ]  The subject might have been a myth or allegory of the underworld, for the cambrian goddess Medusa wore a cravat around her neck so that she would lay upon the body of the dead goddess when she returned to life.
# [ 1 ]  Her skin was soft and smooth, and her eyes bright but beige and bright red.
#
# ### processing response..
# # sentences:  6
# - removing Sentences doesn't have noun or verb:
# ification of death.
# - removing Sentences doesn't have noun or verb:
# He is accompanied by the corpse of his beloved, whom he loves with great devotion.
# - removing Sentences doesn't have noun or verb:
# The composition
#
# # sentences after processing:  3
# [ 0 ]  A richly lithe and elongated figure wearing a richly lacy white gown, lightly bowled, with a large head of gold, is interrupted by a dog who moves in on the moment of his coming out.
# [ 1 ]  In his place lay picturesque ruins, each with its own scene from the past.
# [ 2 ]  A large, twisting, twisted rock faces the viewer from front to back.
#
# ### processing response..
# # sentences:  6
# - removing characters not beginning with letters:
# but she seems to know him.Clutching her hands in his lap, he leans forward.
# - removing Sentences doesn't have noun or verb:
# "I mean, there's just one more thing to go."
# - removing incomplete sentence:
# "You know the one around here: the little tattered piece you saw a year ago?
# - removing characters not beginning with letters:
# "You know, this is going to be the greatest moment of my life," he says, holding the book.
#
# # sentences after processing:  3
# [ 0 ]  You know, this is going to be the greatest moment of my life," he says, holding the book.
# [ 1 ]  He points to her jacket.
# [ 2 ]  Well, it wasn't quite as important..."When Charles II saw that the Temple
#
# ### processing response..
# # sentences:  4
# - removing characters not beginning with letters:
# lying motionless in the center of the room; his legs are exposed, his face darkening slightly at minute 7.
#
# # sentences after processing:  3
# [ 0 ]  He is blind, and could only look up, and has no ear.
# [ 1 ]  His head tilted downward, his face a little disheveled, his skin a little waxy and crumpled with cramps, his forehead a little wet.
# [ 2 ]  His fingers are covered by a tangle of dark, ragged marks, suggesting that he is a victim of a stabbing wound.
#
# ### processing response..
# # sentences:  4
# - removing Sentences doesn't have noun or verb:
# Their status suggests an extraordinary physical and psychological presence.
# - removing Sentences doesn't have noun or verb:
# The female name refers to the goddess Magdalene, who is sometimes portrayed as Magdalene in ancient mythology.
#
# # sentences after processing:  2
# [ 0 ]  In ancient Greece there existed a cult of the male form, usually inscribed with a cross, whose name was inscribed in place of the female form's name instead of a cross on the chest.
# [ 1 ]  Scholars today believe the male form was originally a mythological design, originally intended more as a motif of clothing for religious rites.
#
# ### processing response..
# # sentences:  5
# - removing characters not beginning with letters:
# with their headdress blowing off at their sides.
#
# # sentences after processing:  4
# [ 0 ]  Their eyes gleam in the darkness.
# [ 1 ]  The portrait, as well as the series of other paintings in its collection, were part of a larger set of 1640 and 1810 monumental portraits.
# [ 2 ]  The sculptor in charge, James Hunt, was the native son of an English nobleman and a British aristocrat.
# [ 3 ]  He learned to render, to paint, and to use oil paint, a high art tool that was common in the early Middle Ages.
#
# ### processing response..
# # sentences:  5
# - removing Sentences doesn't have noun or verb:
# The French artists made the costumes in three dimensions but incorporated small details within folds.
#
# # sentences after processing:  4
# [ 0 ]  Renaissance style clothing was not the only feature of this period.
# [ 1 ]  French soldiers had begun to carve the patterns on lapels of this clothing, and the patterned headgear of noblemen was painted on lapels.
# [ 2 ]  The costumes were originally made of leather and were carefully arranged in a large grid patterned cravat.
# [ 3 ]  They were carefully patterned to create a balanced set with different elements of decoration.
#
# ### processing response..
# # sentences:  4
# - removing incomplete sentence:
# Such a monumental composition probably had a pagan sensibility
#
# # sentences after processing:  3
# [ 0 ]  Even the most experienced of the scholars were not able to identify the woman.
# [ 1 ]  According to legend, the Virgin Mary, his faithful companion, saw a young man fall asleep in front of a dark room filled with statues of different gods.
# [ 2 ]  The figure of her ardent lover, kneeling before the image of Hercules, was so iconic in ancient culture that the Roman Emperor Marcus Aurelius ordered the likeness of the Madonna in a central room for all to see.
#
# ### processing response..
# # sentences:  6
# - removing Sentences doesn't have noun or verb:
# on a hillside watching over the river.
# - removing Sentences doesn't have noun or verb:
# The other two have died.
# - removing Sentences doesn't have noun or verb:
# The left part of the globe rests on golden sand.
#
# # sentences after processing:  3
# [ 0 ]  They were depicted in a dark blue, light blue, and yellowish-brown paint.The three figures, represented by an almond to the left of the picture, are both alive and alert.
# [ 1 ]  On their heads are the flowers that they symbolize: a star, sapphire, or gold.
# [ 2 ]  On either side of the globe, which
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# at a distance) have been identified in antiquity and ancient myth.
# - removing incomplete sentence:
# The figures' bodies were then cast into the sarcophagus to await their
#
# # sentences after processing:  1
# [ 0 ]  These were the attendants of the great temple goddess, Aurora, who worshiped with much devotion the dead figures of their deceased victims as part of her ritual sacrifice.
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
# when she was 16, her best friend, the prominent architect Hans Wulffenbach (1437-1572) took her in bed with careful observation, often showing her his hand by the sheets.
#
# # sentences after processing:  1
# [ 0 ]  She would recall how closely she
#
# ### processing response..
# # sentences:  2
# - removing incomplete sentence:
# The artist's skillfully rendered composition is especially charming in portraying the emotion and relief experienced by the grieving man.This is a painting by Bartolomeo Pecchi
#
# # sentences after processing:  1
# [ 0 ]  Having lost his sight, he is partially blinded and has only a few of his eyes functioning.
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# individual whose identity is unknown to his community or other observers.
# - removing incomplete sentence:
# Although the saint was frequently portrayed as a soldier
#
# # sentences after processing:  1
# [ 0 ]  In the mid-eighteenth century artists revived the mythological figure with the likeness of Saint Dominic, the Dominican martyrdom patron during the Protestant Reformation.
#
# ### processing response..
# # sentences:  3
# - removing characters not beginning with letters:
# who stayed at the inn and stayed warm in the winter.As in ancient Homer's mythological events, mythological scenes are treated with some seriousness and urgency by the actors.
# - removing Sentences doesn't have noun or verb:
# The actors are meticulous about the details of the scenes
#
# # sentences after processing:  1
# [ 0 ]  But neither realism nor restraint is appropriate here.
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# on a rocky cliffside.
# - removing Sentences doesn't have noun or verb:
# The shadow cast across her face conveys a melancholy impression.
#
# # sentences after processing:  1
# [ 0 ]  The hatching of the pair provides evidence of the artist's skill in displaying subtle effects at once.This beautiful young female reclines on a rocky cliffside accompanied by other figures.
#
# ### processing response..
# # sentences:  2
# - removing Sentences doesn't have noun or verb:
# sit on one another's lap.
# - removing characters not beginning with letters:
# )The boy in the middle-left corner holds the wicker statue, while the young man in the center smokes a pipe, watches a streamer boil, and drinks a glass of wine from a lager cup.
#
# # sentences after processing:  1
# [ 0 ]  The boy in the middle-left corner holds the wicker statue, while the young man in the center smokes a pipe, watches a streamer boil, and drinks a glass of wine from a lager cup.
#
# ### processing response..
# # sentences:  1
# - removing incomplete sentence:
# so much so that it often inspired a scene from the novel La Cenac: a young man with a wrinkled forehead who looks rather more relaxed than agitated.The artist in this painting was Jean-�tienne Chabry, who painted Saint-La
#
# # sentences after processing:  0
#
# ### processing response..
# # sentences:  2
# - removing Sentences doesn't have noun or verb:
# and then the young lady, with her golden hat, with whom she is associated.
#
# # sentences after processing:  1
# [ 0 ]  The name, Tommaso, from the tritonium, meaning tristram, or trillium, a Roman letter for trincere, relates to the fact that
#
# ### processing response..
# # sentences:  2
# - removing Sentences doesn't have noun or verb:
# or child; this is also sometimes interpreted as an expression of sorrow over the loss of her husband.
#
# # sentences after processing:  1
# [ 0 ]  Other early versions portray the scene as a romantic scene between a rich woman and a wealthy man: now a popular book-length description of the scene in the London Review of Books.After the execution
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
# working in the garden at the top of the church (Antoine D�angere-Clague) would have been the model for the subject of the Virgin Mary's veil.
#
# # sentences after processing:  1
# [ 0 ]  The subject was first popularized in the 1770s by the painter Giovanni Battista di Cattaneo
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# in a rich family of fine, expensive luxuries.
# - removing Sentences doesn't have noun or verb:
# The series, the largest in his career, is almost twice as long as this painting
#
# # sentences after processing:  1
# [ 0 ]  The artist, Jean Paul Gaultier, is usually credited with bringing this splendid series to life, but no one has identified the figure as Michelangelo.
#
# ### processing response..
# # sentences:  3
# - removing characters not beginning with letters:
# on horseback, carrying bricks, bricks, and bricks which have been shattered after being thrown into a river.
# - removing incomplete sentence:
# The space was intended to be used by a priest for mass
#
# # sentences after processing:  1
# [ 0 ]  The painting was probably commissioned in 1633 on a piece of land by the architect Peter Goss.
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
# in blue dress, one of them saying, "You know, if I was dead, I should be making music for the dead," with which the artist poses a serious dilemma.
#
# # sentences after processing:  1
# [ 0 ]  Is the dead person merely a creature of habit or, in the artist's view, a living
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
# while still keeping an open mind.
# - removing characters not beginning with letters:
# "Blessed are those who keep calm amidst hardshipThrough the energy of the Gospel, Saint Clement's emaciated body was identified as that of Anthony the Great, founder of the Church of Santo Stefano in Bologna
#
# # sentences after processing:  1
# [ 0 ]  Blessed are those who keep calm amidst hardshipThrough the energy of the Gospel, Saint Clement's emaciated body was identified as that of Anthony the Great, founder of the Church of Santo Stefano in Bologna
#
# ### processing response..
# # sentences:  3
# - removing characters not beginning with letters:
# while the young king sat cross-legged and reading from a book.
# - removing Sentences doesn't have noun or verb:
# At least three of the four figures in the foreground are aristocrats, while the second wears
# - removing characters not beginning with letters:
# ''Elegance seems the greatest attribute in a picture painted in Northern Italy between 1721 and 1722.
#
# # sentences after processing:  1
# [ 0 ]  Elegance seems the greatest attribute in a picture painted in Northern Italy between 1721 and 1722.
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
# who had a close love of the artist), and the scene is set near the end of the book.Two of a kind landscape architecture is set up at the base of the wall and decorated with a laurel wreath.
#
# # sentences after processing:  1
# [ 0 ]  The rest of the design (four trees and
#
# ### processing response..
# # sentences:  4
# - removing characters not beginning with letters:
# are left lying on the floor.
# - removing incomplete sentence:
# On the crumpled sheets is a cloth saying, "Thou art young
#
# # sentences after processing:  2
# [ 0 ]  A young woman in a flowing white gown rests on the crook of a crook.
# [ 1 ]  Her face is pale pink; she is wearing a red velvet gown.
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# in the sky above a large river valley.
# - removing incomplete sentence:
# It is unknown whether the figures originally intended for this painting were actually the real Christ
#
# # sentences after processing:  1
# [ 0 ]  He depicted the scene as an allegory of winter, with the River Solithim falling from the sky to guide the young men to their safety.
#
# ### processing response..
# # sentences:  2
# - removing Sentences doesn't have noun or verb:
# with whom she confers a blessing.
#
# # sentences after processing:  1
# [ 0 ]  In the background, a large tree with a trunk that extends from the chapel and a crown of seven fingers holds the confessional keys of Jacob and Rebecca and of the Book of Common Prayer.Saint Catherine of Alexandria was once the best
#
# ### processing response..
# # sentences:  4
# - removing characters not beginning with letters:
# gazing up at the sky.
# - removing Sentences doesn't have noun or verb:
# A member of an aristocratic family living in a
#
# # sentences after processing:  2
# [ 0 ]  The figures are all based on the painting.
# [ 1 ]  The painting took a few years to finish in oil paint.This sculpture depicts a scene from the life of a French officer in central Paris.
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
# wearing headdress, with a head of sheep and holding small, wrinkled hands: they seem to symbolize the old and noble past of these artists.
#
# # sentences after processing:  1
# [ 0 ]  In a roundel, Jean-Antoine F�rian and Gustave Courbet painted mournful portraits of the
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# interrupted and began to taunt the Master.
# - removing incomplete sentence:
# During his stay at the farm, the Lord had forced many of these young people to live in
#
# # sentences after processing:  1
# [ 0 ]  At one point the crowd demanded that they be let out of the workshop because the master had locked them up in an ill-fitting room.
#
# ### processing response..
# # sentences:  2
# - removing incomplete sentence:
# While trapped underneath a tree, the group of the flying insect flew away from the tree, spreading their wings to escape the powerful storm
#
# # sentences after processing:  1
# [ 0 ]  After the death of their beloved, the group had to sit with their heads to the floor for four days to let loose a flying insect.
#
# ### processing response..
# # sentences:  3
# - removing characters not beginning with letters:
# sat at a table in the background, watching a dramatic television drama.
# - removing Sentences doesn't have noun or verb:
# Getty Images 23 of 22 Rubens and others made
#
# # sentences after processing:  1
# [ 0 ]  At the far right, a young woman poses for a portrait of Vadim Zola, founder of the court of Plegina in northern Italy.
#
# ### processing response..
# # sentences:  2
# - removing Sentences doesn't have noun or verb:
# The group is meant to remind viewers of an ancient painting in the foreground with its gilt-edged brushwork.
#
# # sentences after processing:  1
# [ 0 ]  The story follows Leonardo da Vinci's father, a master collector at a private collector's workshop in Rome, who decides to create a family painting depicting Italy
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# with her young son.
# - removing incomplete sentence:
# The composition was based on a painting by the late Venetian artist Joffre Ibog�r and was based
#
# # sentences after processing:  1
# [ 0 ]  The painter is an English aristocrat, known primarily for works by his patron, the Venetian painter Moli�.
#
# ### processing response..
# # sentences:  3
# - removing characters not beginning with letters:
# each with their own personality and talents, and trying to make sense of the landscape behind them.
# - removing incomplete sentence:
# His inventive use of colored chalk, which was highly prized in 1633
#
# # sentences after processing:  1
# [ 0 ]  With his brush and the added assistance of a brushstroker, Raphael made this subject of this painting.
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# with their arms crossed in grief as they witness the execution.
# - removing incomplete sentence:
# A group called the
#
# # sentences after processing:  1
# [ 0 ]  In the 1500s artists painted portraits of martyrs and martyr families and took the unusual step of creating elaborate narrative portraits, which seemed to suggest a martyrdom and martyrdom at the same time.
#
# ### processing response..
# # sentences:  3
# - removing characters not beginning with letters:
# standing on a rocky slope, preparing to confront one another.
# - removing Sentences doesn't have noun or verb:
# The shadows cast
#
# # sentences after processing:  1
# [ 0 ]  The artist on the right used a high-pointing color and a slightly different palette than in the print, resulting in vivid, unidirectional lines, suggesting a general spontaneity.
#
# ### processing response..
# # sentences:  1
# - removing incomplete sentence:
# dressed in black, holding a book and their horse.Pronunciation [ edit ]Etymology [ edit ]From Old English mantilla, from Old High German mantel, from Latin mantellum, "headgear", from Old High German mant
#
# # sentences after processing:  0
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# which can only be described as charming and humorous.
# - removing incomplete sentence:
# As depicted in the novel, he was once owned by the wealthy Roman empress, but soon sold to the powerful Bar
#
# # sentences after processing:  1
# [ 0 ]  Knees is a tall, sumptuous figure with an energetic face and graceful flowing locks.
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
# gazing at the viewer in a romantic, kind, and affirming light.This painting was designed for an exhibition held at London's Galleria degli Uffizi in the early 1600s [1].
#
# # sentences after processing:  1
# [ 0 ]  The figure of the gentleman was borrowed from the altarp
#
# ### processing response..
# # sentences:  4
# - removing characters not beginning with letters:
# who appear to be making a gesture of welcome toward one another.
# - removing incomplete sentence:
# His family had
#
# # sentences after processing:  2
# [ 0 ]  Jean-Louis Chacun had once led an elegant life, living modestly in Verona.
# [ 1 ]  A native of the southeastern province of Flanders, he had just turned twenty years old.
#
# ### processing response..
# # sentences:  2
# - removing Sentences doesn't have noun or verb:
# whose characteristic facial features and prominent eyebrows suggest that they are related.
#
# # sentences after processing:  1
# [ 0 ]  The young women, also in the same collection, were among the first to adopt the modern style and to embrace the modern sensibility.A young man sits, nursing a glass of water, while a
#
# ### processing response..
# # sentences:  2
# - removing Sentences doesn't have noun or verb:
# on a panel in which the Virgin Mary appears to Christ in black drapery.
#
# # sentences after processing:  1
# [ 0 ]  The drawing was commissioned by Antonio Girolamo�s son, who had seen the drawing but had not yet seen the painting,�and made by the master himself.The artist
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# and men who are said to have been responsible for torturing Mary (Matthew 16:35-44).
# - removing incomplete sentence:
# These souls were likely victims of religious cult
#
# # sentences after processing:  1
# [ 0 ]  The bodies were recovered from a small wooded area within the traditional family of Martyrs of Christ, the Tolerated Saints.
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# that invaded India around 1400.
# - removing Sentences doesn't have noun or verb:
# After several failed attempts to slay him, King Harpocrates successfully subdued all who opposed him, and he was executed for
#
# # sentences after processing:  1
# [ 0 ]  According to legend, King Harpocrates of India invaded a jealous southern kingdom, and executed a group of his own royalty.
#
# ### processing response..
# # sentences:  1
# - removing incomplete sentence:
# This painting was once on display in the Verona conservatory in Florence.Using a combination of water and chalk, Giulio Credori used a combination of light and shadow to create a shimmering surface that could be identified by the folds of the chalk lines behind
#
# # sentences after processing:  0
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# were created for each other.
# - removing incomplete sentence:
# They are not intended to be identified by their unusual faces, which might indicate social or psychological roles.The painting was commissioned by
#
# # sentences after processing:  1
# [ 0 ]  The leftmost figure depicts a boy and girl, who are seen gazing sadly at one another as if frightened.
#
# ### processing response..
# # sentences:  2
# - removing Sentences doesn't have noun or verb:
# Above all, though,
#
# # sentences after processing:  1
# [ 0 ]  What he saw was not a scene from a typical fantasy story, but rather one in which one could identify many of the elements: light, shadow, and warm colors, which formed the background to many of the surface areas of this painting.
#
# ### processing response..
# # sentences:  2
# - removing incomplete sentence:
# Oddly, though, the pipe is only partially illuminated, giving the painting's owner a
#
# # sentences after processing:  1
# [ 0 ]  This painting depicts a youth attempting to follow a pipe dream: during the painting's final resting moment, an unknown person reaches up and pulls a pipe up the child's chest.
#
# ### processing response..
# # sentences:  2
# - removing characters not beginning with letters:
# she is often portrayed as a kind, kindling angel, whom the Church has recognized as a faithful patron.
#
# # sentences after processing:  1
# [ 0 ]  The Catholic Church interpreted these words with greater sensitivity than it had in the early 20th century, and some scholars believe that Christ's Mercy may have been intended as
#
# ### processing response..
# # sentences:  3
# - removing Sentences doesn't have noun or verb:
# A priestess is abducted by the demons, while her lover, Saint Vianney, is captured and tortured.
# - removing Sentences doesn't have noun or verb:
# His impetuous expression
#
# # sentences after processing:  1
# [ 0 ]  Vianney turns to a mystic, Saint Sebastian, who gives impassioned recitations of mantras to the priestess.
#
# ### processing response..
# # sentences:  2
# - removing Sentences doesn't have noun or verb:
# with an extraordinary rendition of the ancient Egyptian scene from The Odyssey.
#
# # sentences after processing:  1
# [ 0 ]  Here the sculptor employed an unusual approach to forming a scene that contrasted with conventional perspective, and was also sensitive to the emotional and psychological effects of light.The figure of a seated man with His features plain
#
# ### processing response..
# # sentences:  2
# - removing Sentences doesn't have noun or verb:
# while still remaining emotionally stable.
#
# # sentences after processing:  1
# [ 0 ]  These are figures that have captivated audiences since their conception, yet often failed to achieve their originality.In the 1700s, artists began creating decorative or decorative garments in response to the popular demand for a fashionable, open-topped
#
# ### processing response..
# # sentences:  2
# - removing Sentences doesn't have noun or verb:
# Titian's work emphasizes the fleeting nature of
#
# # sentences after processing:  1
# [ 0 ]  Her hair is very long, but she still leans forward and poses with a dignified air.In order to describe the female figure, S�vres and his son copied scenes from the ancient Greek and Roman mythology.
# ['Known for his skillfully rendered characters, complex gestures, and varied animation styles, Edgar Degas often epitomized the visionary.', "According to Herodotus,risenas, or grapes, were used to glaze Roman columns and battlements, which then decorated the temple's walls.", 'CollectorsReturning to his hunting grounds, the distraught woman leans on a rope frame made of obsidian, attempting to pull herself up by her hair', 'Suspecting that the condemned man was a kidnapper, the kidnapper�s identity was revealed as that of the new governor of the kingdom of', 'The nymphs stand on the precip', 'L\'Anse wrote, "I shall make a bed in his garden, and when it is time to let him into the world, I shall set it on fire with his naked body against the mantel.', 'Yet the intimacy and serenity of his life also includes the freshness of his disposition, the changing of the season in the distance, and the frequency of lullaby songs.', 'The speaker assumes the form of a youth, leaning on one arm and extending out sharply and dramatically to address the viewer at a time.', "The painting's linear composition is characteristic of Bartolommeo�  (1679 � 1707) of the River Titian, a prominent Florentine artist who influenced Pino a generation later.", 'Against the sober, tragic landscape, his character is more like a short film than a full-length.', "His great advantage is his ability to give facial expressions since the smaller the head, the wider, more eminent his other features become in a woman's body.", 'At his left a woman holds a wreath, while a man with a cape and a hood holds a jewel.', 'A woman', 'Separated from his family by a violent storm, Samuel has retreated to the shade of a tree by his side, where he engages in merry adventuring.', '325 - 337) that was also by Rogelio Landes', 'The grain is smooth, creamy, and quite a departure from the crinkled silver and gold that characterized so many other porcelain prints made during this period.', 'I sit in a reclining position on a chair and lean against the wall while a woman in a low sitting position stares down from her terraced terrace with an expression of concern.', 'Día Ferreira was appointed', 'His favorite subject, the small lion--a symbol of peasant status in Israel--has been suggested earlier by Tzachi Bright (1713�1816), who observed that the joyful young man would be', "This procession of picturesque peasant scenes is called a tous-vous de l'ame (tous'-vaous-il-le-mi-ame)?", 'As was customary in the prime of Italian civil government, the Crown appointed members of the press and royal courts with important', 'In so doing, he recognized that his subject already possessed considerable literary talent.', "According to Vincent, Fran�ois-Joseph D�rer was once considered one of France's most prolific writers and essayists, and his writings often circulated in the press.", "Responding to the viewer's request for a pose that encourages foreshortening, he encourages the viewer to sit still and recall his thoughts for as long as possible.", 'Tender grapes, rich in vitamin C, may even be added to the blend to taste.', 'The anticipatory pose, as adopted by Johann Karl Wilhelm von Haas, emphasizes', 'He used subtle but powerful strokes to show off his athletic strength and musculara', 'Thus the emperor, now crowned by King David, began his conquest of Babylon and', 'Fortuna, a young girl in a yellow robe, kneels to contemplate her father,', 'Though pale he was not greedy or greedy� he was simply looking for love.', 'In high spirits he holds', 'The story relates to a story with contemporary Christian evangelist Giorgio Vasari, who was visiting Rome as consul to Holland', 'In this retelling of the founding of the Jewish community of Palisades, Luigi Gentile was one of the first collectors to study religious figures in detail.', "The figures' facial features are similar to those of ancient Egyptian art (these figures, which were usually empty", 'She combines a sensuality bordering on eroticism ...
